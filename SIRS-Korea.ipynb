# %% [markdown]
# # Models with immunity
#
# ## SIR-O - a modified SIR with explicit confirmed cases
# This model is modified [SIR](https://en.wikipedia.org/wiki/Compartmental_models_in_epidemiology#The_SIR_model):
# - **S** is *Susceptible*
# - **I** is *Infectious*
# - **R** is *Recovered* (and *diseased*). The model expects that this pool becomes 100% immune.
# - **O** is *cOnfirmed* individuals, both hospitalized and quorantined at home with a positive test
#
# The model utilises three parameters: $\alpha$,$\beta$ and $k$:
# - $\alpha$ models the speed of infection spread,
# - $\beta$ represents the speed of recovery (and deaths)
# - $k$ is the reveal factor, how many infectious people are confirmed as positive.
#
# The differential equations:<br>
# $\frac{dS}{dt} = -\alpha S I$,<br>
# $\frac{dI}{dt} = \alpha S I - \beta I$, <br>
# $\frac{dR}{dt} = \beta I$,<br>
# $\frac{dO}{dt} = k I$.
#
#
# # Models without immunity
#
# ## SIRS-O - a SIR model without antigen and with explicit confirmed cases
# This model is modified [SIR](https://en.wikipedia.org/wiki/Compartmental_models_in_epidemiology#The_SIR_model):
# - **S** is *Succeptible*
# - **I** is *Infectious*
# - **R** is *Recovered* (and *diseased*). While in **R** state people are immune.
# - **O** is *cOnfirmed* individuals, both hospitalized and quorantined at home with a positive test
#
# The major feature of this model is conversion of some or recovered back into succeptible.
#
# The model utilises three parameters: $\alpha$,$\beta$ and $k$:
# - $\alpha$ models the speed of infection spread,
# - $\beta$ represents the speed of recovery (and deaths),
# - $r_s$ is the ratio of recovered people who are susceptible again,
# - $k$ is the reveal factor, how many infectious people are confirmed as positive.
#
# The differential equations:
# $\frac{dS}{dt} = -\alpha S I + r_s R$,<br>
# $\frac{dI}{dt} = \alpha S I - \beta I$, <br>
# $\frac{dR}{dt} = \beta I - r_s R$,<br>
# $\frac{dO}{dt} = k I$.
#
# ## SIRC-O - a SIR model with carriers and with explicit confirmed cases
# This model is modified [SIR](https://en.wikipedia.org/wiki/Compartmental_models_in_epidemiology#The_SIR_model):
# - **S** is *Succeptible*
# - **I** is *Infectious*, i.e. with syptoms of the disease.
# - **C** is *Carrier*, i.e. infectious, but without symptoms or actual illness.
# - **R** is *Recovered* (and *diseased*). While in **R** state people are immune.
# - **O** is *cOnfirmed* individuals, both hospitalized and quorantined at home with a positive test
#
# The major feature of this model is having people carry the virus and infect others without actually being ill.
#
# The model utilises three parameters: $\alpha$,$\beta$ and $k$:
# - $\alpha$ models the speed of infection spread,
# - $\beta$ represents the speed of recovery (and deaths),
# - $c_s$ models efficiency of infection transmission by carriers compared to infectious.
# - $i_r$ is the ratio of infectious, who recovered (became immune), and $1 - i_r$ become carriers.
# - $c_r$ represents the speed of recovery of carriers.
# - $k$ is the reveal factor, how many infectious people are confirmed as positive.
#
# The differential equations:
# $\frac{dS}{dt} = -\alpha S I - c_s \alpha S C$,<br>
# $\frac{dI}{dt} = \alpha S I + c_s \alpha S C - \beta I$, <br>
# $\frac{dR}{dt} = \beta i_r I$,<br>
# $\frac{dC}{dt} = \beta (1 - i_r) I$,<br>
# $\frac{dO}{dt} = k (I + C)$.

# %%
country  = 'Korea, South'
country2 = 'Korea, Rep.'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numba import jit
from scipy.integrate import odeint
from datetime import datetime

# %matplotlib inline

# %%
print("Computed on: ", datetime.now().strftime(format='%y-%m-%d %T'))
# Out:
# Computed on:  20-05-08 18:44:24

# %%
import corona

# %%
info = corona.CovidModel(country, country2)
print("Country: ", info.country)
print("Population: ", info.population)
print("Number of revealed cases: ", info.data[0][-1])
print("Number of deaths: ", info.data[1][-1])
# Out:
# Country:  Korea, South
# Population:  51606633.0
# Number of revealed cases:  10822
# Number of deaths:  256

# %%
delta = info.data[:,1:] - info.data[:,:-1]

days = np.arange(np.shape(delta)[1])
fig, ax1 = plt.subplots()

ax1.bar(days, delta[0], width=1.0)
ax1.set_ylabel('Cases per day')

ax2 = ax1.twinx()
ax2.plot(days, info.data[0][1:], 'o', color='red')
ax2.set_ylabel('Total number of cases')
fig.tight_layout()

plt.title(info.country + ": COVID19 stats");

# %% [markdown]
# # Models without immunity

# %% [markdown]
# ## Some of recovered become susceptible again

# %%
test_sirs = corona.CovidModel(country, country2, model='sir_so_r0')
test_sirs.run(300)
# Out:
# Progress: [####################] 100.0% 201.52272032955963
# <style  type="text/css" >
# </style><table id="T_955edecc_9110_11ea_b598_ac1f6b47489c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >alpha</th>        <th class="col_heading level0 col1" >beta</th>        <th class="col_heading level0 col2" >recovered to susceptible</th>        <th class="col_heading level0 col3" >reveal efficiency</th>        <th class="col_heading level0 col4" >Infected initial</th>        <th class="col_heading level0 col5" >Recovered initial</th>        <th class="col_heading level0 col6" >R0</th>        <th class="col_heading level0 col7" >Precision</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_955edecc_9110_11ea_b598_ac1f6b47489clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow0_col0" class="data row0 col0" >0.727</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow0_col1" class="data row0 col1" >0.115</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow0_col2" class="data row0 col2" >2.08e-05</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow0_col3" class="data row0 col3" >0.00757</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow0_col4" class="data row0 col4" >11.0</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow0_col5" class="data row0 col5" >0.0</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow0_col6" class="data row0 col6" >6.31</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow0_col7" class="data row0 col7" >202</td>
#             </tr>
#             <tr>
#                         <th id="T_955edecc_9110_11ea_b598_ac1f6b47489clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow1_col0" class="data row1 col0" >3.12</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow1_col1" class="data row1 col1" >2.88</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow1_col2" class="data row1 col2" >0.00292</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow1_col3" class="data row1 col3" >0.0277</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow1_col4" class="data row1 col4" >409.0</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow1_col5" class="data row1 col5" >0.0</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow1_col6" class="data row1 col6" >1.08</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow1_col7" class="data row1 col7" >341</td>
#             </tr>
#             <tr>
#                         <th id="T_955edecc_9110_11ea_b598_ac1f6b47489clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow2_col0" class="data row2 col0" >3.25</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow2_col1" class="data row2 col1" >3.01</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow2_col2" class="data row2 col2" >0.00317</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow2_col3" class="data row2 col3" >0.0278</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow2_col4" class="data row2 col4" >374.5</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow2_col5" class="data row2 col5" >0.0</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow2_col6" class="data row2 col6" >1.08</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow2_col7" class="data row2 col7" >341</td>
#             </tr>
#             <tr>
#                         <th id="T_955edecc_9110_11ea_b598_ac1f6b47489clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow3_col0" class="data row3 col0" >3.3</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow3_col1" class="data row3 col1" >3.07</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow3_col2" class="data row3 col2" >0.00328</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow3_col3" class="data row3 col3" >0.0278</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow3_col4" class="data row3 col4" >363.5</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow3_col5" class="data row3 col5" >0.0</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow3_col6" class="data row3 col6" >1.08</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow3_col7" class="data row3 col7" >341</td>
#             </tr>
#             <tr>
#                         <th id="T_955edecc_9110_11ea_b598_ac1f6b47489clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow4_col0" class="data row4 col0" >3.33</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow4_col1" class="data row4 col1" >3.09</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow4_col2" class="data row4 col2" >0.00333</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow4_col3" class="data row4 col3" >0.0278</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow4_col4" class="data row4 col4" >358.7</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow4_col5" class="data row4 col5" >0.0</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow4_col6" class="data row4 col6" >1.08</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow4_col7" class="data row4 col7" >341</td>
#             </tr>
#             <tr>
#                         <th id="T_955edecc_9110_11ea_b598_ac1f6b47489clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow5_col0" class="data row5 col0" >3.33</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow5_col1" class="data row5 col1" >3.09</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow5_col2" class="data row5 col2" >0.00334</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow5_col3" class="data row5 col3" >0.0278</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow5_col4" class="data row5 col4" >358.3</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow5_col5" class="data row5 col5" >0.0</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow5_col6" class="data row5 col6" >1.08</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow5_col7" class="data row5 col7" >341</td>
#             </tr>
#             <tr>
#                         <th id="T_955edecc_9110_11ea_b598_ac1f6b47489clevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow6_col0" class="data row6 col0" >3.33</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow6_col1" class="data row6 col1" >3.09</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow6_col2" class="data row6 col2" >0.00334</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow6_col3" class="data row6 col3" >0.0278</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow6_col4" class="data row6 col4" >356.3</td>
#                         <td id="T_955edecc_9110_11ea_b598_ac1f6b47489crow6_col5" class="data row6 col5" >0.0</td>

# %% [markdown]
# ## Part of the population are symptom-less infectious carriers
# Recovered posess immunity

# %%
test_sirc = corona.CovidModel(country, country2, model='sir_co')
test_sirc.run(300)
# Out:
# Progress: [####################] 100.0% 348.96208379668866
# <style  type="text/css" >
# </style><table id="T_b5de86ac_9110_11ea_b598_ac1f6b47489c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >alpha</th>        <th class="col_heading level0 col1" >beta</th>        <th class="col_heading level0 col2" >carrier efficiency</th>        <th class="col_heading level0 col3" >infectious to recovered</th>        <th class="col_heading level0 col4" >carrier recovery</th>        <th class="col_heading level0 col5" >reveal efficiency</th>        <th class="col_heading level0 col6" >Initial infected</th>        <th class="col_heading level0 col7" >Initial carrier</th>        <th class="col_heading level0 col8" >Initial recovered</th>        <th class="col_heading level0 col9" >R0</th>        <th class="col_heading level0 col10" >Precision</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b5de86ac_9110_11ea_b598_ac1f6b47489clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow0_col0" class="data row0 col0" >3.27</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow0_col1" class="data row0 col1" >3.64</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow0_col2" class="data row0 col2" >0.0982</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow0_col3" class="data row0 col3" >0.668</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow0_col4" class="data row0 col4" >0.179</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow0_col5" class="data row0 col5" >0.000166</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow0_col6" class="data row0 col6" >580.8</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow0_col7" class="data row0 col7" >2026.0</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow0_col8" class="data row0 col8" >9.8</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow0_col9" class="data row0 col9" >0.899</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow0_col10" class="data row0 col10" >349</td>
#             </tr>
#             <tr>
#                         <th id="T_b5de86ac_9110_11ea_b598_ac1f6b47489clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow1_col0" class="data row1 col0" >2.28</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow1_col1" class="data row1 col1" >2.56</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow1_col2" class="data row1 col2" >0.78</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow1_col3" class="data row1 col3" >0.937</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow1_col4" class="data row1 col4" >0.372</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow1_col5" class="data row1 col5" >0.00117</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow1_col6" class="data row1 col6" >469.9</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow1_col7" class="data row1 col7" >1744.6</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow1_col8" class="data row1 col8" >721.5</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow1_col9" class="data row1 col9" >0.893</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow1_col10" class="data row1 col10" >450</td>
#             </tr>
#             <tr>
#                         <th id="T_b5de86ac_9110_11ea_b598_ac1f6b47489clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow2_col0" class="data row2 col0" >2.3</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow2_col1" class="data row2 col1" >2.35</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow2_col2" class="data row2 col2" >0.803</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow2_col3" class="data row2 col3" >0.967</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow2_col4" class="data row2 col4" >0.387</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow2_col5" class="data row2 col5" >0.00165</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow2_col6" class="data row2 col6" >25.5</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow2_col7" class="data row2 col7" >12.5</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow2_col8" class="data row2 col8" >648.6</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow2_col9" class="data row2 col9" >0.981</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow2_col10" class="data row2 col10" >466</td>
#             </tr>
#             <tr>
#                         <th id="T_b5de86ac_9110_11ea_b598_ac1f6b47489clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow3_col0" class="data row3 col0" >1.58</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow3_col1" class="data row3 col1" >2.04</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow3_col2" class="data row3 col2" >0.743</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow3_col3" class="data row3 col3" >0.709</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow3_col4" class="data row3 col4" >0.893</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow3_col5" class="data row3 col5" >0.000969</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow3_col6" class="data row3 col6" >2195.0</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow3_col7" class="data row3 col7" >408.6</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow3_col8" class="data row3 col8" >2196.5</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow3_col9" class="data row3 col9" >0.771</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow3_col10" class="data row3 col10" >505</td>
#             </tr>
#             <tr>
#                         <th id="T_b5de86ac_9110_11ea_b598_ac1f6b47489clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow4_col0" class="data row4 col0" >3.1</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow4_col1" class="data row4 col1" >3.39</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow4_col2" class="data row4 col2" >0.184</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow4_col3" class="data row4 col3" >0.724</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow4_col4" class="data row4 col4" >0.956</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow4_col5" class="data row4 col5" >0.00239</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow4_col6" class="data row4 col6" >725.4</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow4_col7" class="data row4 col7" >1639.1</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow4_col8" class="data row4 col8" >1365.6</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow4_col9" class="data row4 col9" >0.915</td>
#                         <td id="T_b5de86ac_9110_11ea_b598_ac1f6b47489crow4_col10" class="data row4 c

# %% [markdown]
# ## Part of the population are symptom-less infectious carriers, and recovered loose the immunity

# %%
test_sir_sco = corona.CovidModel(country, country2, model='sir_sco')
test_sir_sco.run(300)
# Out:
# Progress: [####################] 100.0% 288.35880449562836
# <style  type="text/css" >
# </style><table id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >alpha</th>        <th class="col_heading level0 col1" >beta</th>        <th class="col_heading level0 col2" >carrier efficiency</th>        <th class="col_heading level0 col3" >infectious to recovered</th>        <th class="col_heading level0 col4" >carrier recovery</th>        <th class="col_heading level0 col5" >recovered to susceptible</th>        <th class="col_heading level0 col6" >reveal efficiency</th>        <th class="col_heading level0 col7" >Initial infected</th>        <th class="col_heading level0 col8" >Initial carrier</th>        <th class="col_heading level0 col9" >Initial recovered</th>        <th class="col_heading level0 col10" >R0</th>        <th class="col_heading level0 col11" >Precision</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow0_col0" class="data row0 col0" >2.67</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow0_col1" class="data row0 col1" >2.97</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow0_col2" class="data row0 col2" >0.484</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow0_col3" class="data row0 col3" >0.88</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow0_col4" class="data row0 col4" >0.478</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow0_col5" class="data row0 col5" >0.0239</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow0_col6" class="data row0 col6" >0.000777</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow0_col7" class="data row0 col7" >34.5</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow0_col8" class="data row0 col8" >22.9</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow0_col9" class="data row0 col9" >304.1</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow0_col10" class="data row0 col10" >0.899</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow0_col11" class="data row0 col11" >288</td>
#             </tr>
#             <tr>
#                         <th id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow1_col0" class="data row1 col0" >2.84</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow1_col1" class="data row1 col1" >3.52</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow1_col2" class="data row1 col2" >0.727</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow1_col3" class="data row1 col3" >0.757</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow1_col4" class="data row1 col4" >1.67</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow1_col5" class="data row1 col5" >0.0272</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow1_col6" class="data row1 col6" >0.00187</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow1_col7" class="data row1 col7" >494.5</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow1_col8" class="data row1 col8" >741.5</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow1_col9" class="data row1 col9" >68.1</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow1_col10" class="data row1 col10" >0.807</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow1_col11" class="data row1 col11" >335</td>
#             </tr>
#             <tr>
#                         <th id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow2_col0" class="data row2 col0" >2.53</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow2_col1" class="data row2 col1" >2.75</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow2_col2" class="data row2 col2" >0.396</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow2_col3" class="data row2 col3" >0.63</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow2_col4" class="data row2 col4" >2</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow2_col5" class="data row2 col5" >0.0273</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow2_col6" class="data row2 col6" >0.00147</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow2_col7" class="data row2 col7" >295.2</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow2_col8" class="data row2 col8" >142.5</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow2_col9" class="data row2 col9" >758.5</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow2_col10" class="data row2 col10" >0.922</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow2_col11" class="data row2 col11" >338</td>
#             </tr>
#             <tr>
#                         <th id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow3_col0" class="data row3 col0" >2.02</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow3_col1" class="data row3 col1" >2.28</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow3_col2" class="data row3 col2" >0.588</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow3_col3" class="data row3 col3" >0.496</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow3_col4" class="data row3 col4" >2.5</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow3_col5" class="data row3 col5" >0.0273</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow3_col6" class="data row3 col6" >0.0011</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow3_col7" class="data row3 col7" >276.8</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow3_col8" class="data row3 col8" >763.0</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow3_col9" class="data row3 col9" >1374.4</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow3_col10" class="data row3 col10" >0.886</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow3_col11" class="data row3 col11" >338</td>
#             </tr>
#             <tr>
#                         <th id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow4_col0" class="data row4 col0" >2.62</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow4_col1" class="data row4 col1" >2.4</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow4_col2" class="data row4 col2" >0.0385</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow4_col3" class="data row4 col3" >0.87</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow4_col4" class="data row4 col4" >1.57</td>
#                         <td id="T_d55f0ec0_9110_11ea_b598_ac1f6b47489crow4_col5" class="data row4 col5" >0.0275</td>
#                         <td i

# %% [markdown]
# ## Experimental model with carriers and no immunity
# The major change from the previous model - difference in revealing efficiency for infectious and carriers

# %%
test_sir_sco_kc = corona.CovidModel(country, country2, model='sir_sco_kc')
test_sir_sco_kc.run(300)
# Out:
# Progress: [####################] 100.0% 330.9285886052455
# <style  type="text/css" >
# </style><table id="T_f4361744_9110_11ea_b598_ac1f6b47489c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >alpha</th>        <th class="col_heading level0 col1" >beta</th>        <th class="col_heading level0 col2" >carrier efficiency</th>        <th class="col_heading level0 col3" >infectious to recovered</th>        <th class="col_heading level0 col4" >carrier recovery</th>        <th class="col_heading level0 col5" >recovered to susceptible</th>        <th class="col_heading level0 col6" >Infectious reveal efficiency</th>        <th class="col_heading level0 col7" >Carrier reveal efficiency</th>        <th class="col_heading level0 col8" >Initial infected</th>        <th class="col_heading level0 col9" >Initial carrier</th>        <th class="col_heading level0 col10" >Initial recovered</th>        <th class="col_heading level0 col11" >R0</th>        <th class="col_heading level0 col12" >Precision</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f4361744_9110_11ea_b598_ac1f6b47489clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow0_col0" class="data row0 col0" >2.73</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow0_col1" class="data row0 col1" >3.6</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow0_col2" class="data row0 col2" >0.338</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow0_col3" class="data row0 col3" >0.493</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow0_col4" class="data row0 col4" >1.29</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow0_col5" class="data row0 col5" >0.0266</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow0_col6" class="data row0 col6" >0.00259</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow0_col7" class="data row0 col7" >4.92e-07</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow0_col8" class="data row0 col8" >19.7</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow0_col9" class="data row0 col9" >461.5</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow0_col10" class="data row0 col10" >1299.6</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow0_col11" class="data row0 col11" >0.758</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow0_col12" class="data row0 col12" >331</td>
#             </tr>
#             <tr>
#                         <th id="T_f4361744_9110_11ea_b598_ac1f6b47489clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow1_col0" class="data row1 col0" >2.79</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow1_col1" class="data row1 col1" >3.18</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow1_col2" class="data row1 col2" >0.371</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow1_col3" class="data row1 col3" >0.78</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow1_col4" class="data row1 col4" >0.935</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow1_col5" class="data row1 col5" >0.0257</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow1_col6" class="data row1 col6" >0.00143</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow1_col7" class="data row1 col7" >0.00119</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow1_col8" class="data row1 col8" >451.6</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow1_col9" class="data row1 col9" >472.7</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow1_col10" class="data row1 col10" >673.5</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow1_col11" class="data row1 col11" >0.877</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow1_col12" class="data row1 col12" >333</td>
#             </tr>
#             <tr>
#                         <th id="T_f4361744_9110_11ea_b598_ac1f6b47489clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow2_col0" class="data row2 col0" >1.73</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow2_col1" class="data row2 col1" >1.51</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow2_col2" class="data row2 col2" >0.361</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow2_col3" class="data row2 col3" >0.92</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow2_col4" class="data row2 col4" >2.28</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow2_col5" class="data row2 col5" >0.0268</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow2_col6" class="data row2 col6" >0.000689</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow2_col7" class="data row2 col7" >0.00298</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow2_col8" class="data row2 col8" >763.9</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow2_col9" class="data row2 col9" >319.9</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow2_col10" class="data row2 col10" >1584.1</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow2_col11" class="data row2 col11" >1.14</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow2_col12" class="data row2 col12" >334</td>
#             </tr>
#             <tr>
#                         <th id="T_f4361744_9110_11ea_b598_ac1f6b47489clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow3_col0" class="data row3 col0" >3.01</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow3_col1" class="data row3 col1" >3.87</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow3_col2" class="data row3 col2" >0.717</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow3_col3" class="data row3 col3" >0.721</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow3_col4" class="data row3 col4" >1.89</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow3_col5" class="data row3 col5" >0.0274</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow3_col6" class="data row3 col6" >0.00203</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow3_col7" class="data row3 col7" >0.00231</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow3_col8" class="data row3 col8" >502.5</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow3_col9" class="data row3 col9" >879.9</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow3_col10" class="data row3 col10" >12.5</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow3_col11" class="data row3 col11" >0.78</td>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow3_col12" class="data row3 col12" >337</td>
#             </tr>
#             <tr>
#                         <th id="T_f4361744_9110_11ea_b598_ac1f6b47489clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f4361744_9110_11ea_b598_ac1f6b47489crow4_col0" class="data row4 col0" >2.73</td>
#                         <td id="T_f

# %% [markdown]
# ## Model with incubation period and no immunity (SEIRS)

# %%
test_seir_so = corona.CovidModel(country, model='seir_so')
test_seir_so.run(300)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-eec941cee8f6> in <module>
# ----> 1 test_seir_so = corona.CovidModel(country, model='seir_so')
#       2 test_seir_so.run(300)
#
# ~/tmp/tmp-coronavid/COVID-19-BO-SIRX/corona.py in __init__(self, country, population_db_country_name, population, model)
#     406                     else:
#     407                         population_db_country_name = self.country
# --> 408                 self.population = PopulationData()[population_db_country_name]
#     409             else:
#     410                 self.population = population
#
# ~/tmp/tmp-coronavid/COVID-19-BO-SIRX/corona.py in __getitem__(self, key)
#      85
#      86     def __getitem__(self, key):
# ---> 87         return self._ensure().population[key]
#      88
#      89     def countries(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4742                     raise InvalidIndexError(key)
#    4743                 else:
# -> 4744                     raise e1
#    4745             except Exception:  # pragma: no cover
#    4746                 raise e1
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Korea, South'

# %% [markdown]
# # Models with immunity

# %% [markdown]
# ## SIR - the basic epidemiology model

# %%
test_sir = corona.CovidModel(country, country2, model='sir_o_r0')

test_sir.run(500, figsize=(10, 6))

# %% [markdown]
# ## Model with exposed (incubation period)

# %%
test_seir = corona.CovidModel(country, model='seir_o')

test_seir.run(300)
